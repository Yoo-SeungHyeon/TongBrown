# %%
import requests
from bs4 import BeautifulSoup
import cx_Oracle
import re
import numpy as np

# %%
cx_Oracle.init_oracle_client(lib_dir=r"C:\instantclient-basic-windows.x64-21.9.0.0.0dbru\instantclient_21_9")

# %%
def cleansing_sentence(input_string):
    string_pattern = re.compile(r'[^ㄱ-힣 0-9 a-z A-Z]')
    cleansing_string = string_pattern.sub('', input_string)
    return cleansing_string

# %%
def url_parsing(response,url_code):
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        div = soup.select_one('div.list_content')

        titles = div.select('div > div > a > span.subject_fixed')
        counts = div.select('div > div > span.hit')
        date = div.select('div > div > span > span.timestamp')
        # link = div.select('div >div > a.list_subject')
        title_list =[]
    
        i=0
        for title in titles:
            title = cleansing_sentence(title.get_text())
            title_list.append(title.strip())
            counts[i] = counts[i].get_text().strip()
            date[i] = date[i].get_text().strip()
            #link[i] = link[i].get('href')
            print("제목 : ",title_list[i])
            print("조회수 : ",counts[i])
            print("날짜 : ",date[i])
            #print("링크 : ",link[i])
            print("-----------------------------------------------")
        
            i = i + 1
        #db_insert(url_code,title_list, counts,date,link)
        db_insert(url_code,title_list, counts,date)

# %%
def db_insert(url_code,title_list, counts, date): # DB 저장 함수(크롤링 추출 자료 INSET)
    conn = cx_Oracle.connect(user='admin', password='Tongbrown@23', dsn='tongbrown_high')

    print('')
    print('DB connect 성공!!')
    print('')

    cs = conn.cursor()

    sql = "INSERT INTO clien_test_table1 (CODE_URL,DATA_TITLE,DATA_COUNT,DATE_WRITE, EXTRACT_DATE,id) VALUES (:1,:2,:3,:4,TO_CHAR(SYSDATE,'YYYYMMDD'),clien_sequence.NEXTVAL)"

    i = 0
    for title in title_list:
        cs.execute(sql, (url_code, title_list[i], counts[i],date[i]))
        i = i + 1
        
    print("[%d]건 INSERT 완료" % 30)
    cs.close()
    conn.commit()
    conn.close()

# %%
conn = cx_Oracle.connect(user='admin', password='Tongbrown@23', dsn='tongbrown_high')

print('')
print('DB connect 성공!!')
print('')

cs = conn.cursor()

    
sql_get1 = """  SELECT * FROM head_table1 """   
cs.execute(sql_get1)
head_rows1 = cs.fetchone()
head_rows1[1]
# Out:
# DB connect 성공!!
# '흔들리는 2차전지'

# %%
def re_url():
    for page in range(5,10):
        url2 = "https://www.clien.net/service/board/cm_stock?&od=T31&category=0&po={}".format(str(page))
        url_code = "03"
        response = requests.get(url2)
        url_parsing(response,url_code)
        print("\n\n\n\n\n\n",page)

# %%
conn = cx_Oracle.connect(user='admin', password='Tongbrown@23', dsn='tongbrown_high')

print('')
print('DB connect 성공!!')
print('')

cs = conn.cursor()

sql_get = """  SELECT * FROM clien_test_table1
                    WHERE ROWNUM =1 """   
cs.execute(sql_get)
head_rows = cs.fetchall()

url= ""
title=""
count = ""
date=""
write=""
id=""


count=1

for i in head_rows:
    if count == 1:
        url     = i[0]
        title   = i[1]
        count   = i[2]
        date    = i[3]
        write   = i[4]
        id      = i[5]
        count = 0
    else:
        break


sql_head = """  insert into head_table1 (CODE_URL,DATA_TITLE,DATA_COUNT,DATE_WRITE, EXTRACT_DATE,id) 
                VALUES (:CODE_URL,:DATA_TITLE,:DATA_COUNT,:DATE_WRITE,:EXTRACT_DATE,:id)
                """
cs.execute(sql_head,CODE_URL=url,DATA_TITLE=title,DATA_COUNT=count,DATE_WRITE=write, EXTRACT_DATE=date,id=id)

cs.close() 
conn.commit()
conn.close()

print(head_rows)
# Out:
# DB connect 성공!!
#
# [('03', '흔들리는 2차전지', '3972', '20230521', '2023-05-08 18:24:51', 51430)]

# %%
if __name__ == '__main__':
    re_url()
# Out:
# 제목 :  로이터 버크셔 해서웨이 중국 BYD 주식 5890만 달러어치 매각
# 조회수 :  3249
# 날짜 :  2023-05-11 14:05:19
# -----------------------------------------------
# 제목 :  주식과는 1도 상관없는 주식 관련 징크스
# 조회수 :  2359
# 날짜 :  2023-05-11 12:43:27
# -----------------------------------------------
# 제목 :  中 4월 생산자물가 36 디플레이션 장기국면
# 조회수 :  2200
# 날짜 :  2023-05-11 12:25:48
# -----------------------------------------------
# 제목 :  CFD랑 신용이랑은 다른 거였네요
# 조회수 :  2025
# 날짜 :  2023-05-11 12:04:42
# -----------------------------------------------
# 제목 :  지표 중국 소비자생산자 물가지수 예측 하회jpg
# 조회수 :  1383
# 날짜 :  2023-05-11 10:53:04
# -----------------------------------------------
# 제목 :  5월 미 CPI 발표 일정
# 조회수 :  2137
# 날짜 :  2023-05-11 09:52:35
# -----------------------------------------------
# 제목 :  호주 정치 현황공화정 여론 압도적jpg
# 조회수 :  1526
# 날짜 :  2023-05-11 08:00:37
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 510 수 영문
# 조회수 :  1257
# 날짜 :  2023-05-11 00:54:28
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 510 수 영문
# 조회수 :  1943
# 날짜 :  2023-05-11 00:53:08
# -----------------------------------------------
# 제목 :  찰리 빌렐로  4월 미국 CPI 세부 수치 분석
# 조회수 :  2939
# 날짜 :  2023-05-10 23:40:36
# -----------------------------------------------
# 제목 :  테슬라 오르나요
# 조회수 :  6473
# 날짜 :  2023-05-10 22:46:42
# -----------------------------------------------
# 제목 :  농담 오늘은 오를 겁니다
# 조회수 :  3263
# 날짜 :  2023-05-10 22:32:04
# -----------------------------------------------
# 제목 :  美 4월 근원 CPI 전월비 04예상 부합
# 조회수 :  3708
# 날짜 :  2023-05-10 21:44:14
# -----------------------------------------------
# 제목 :  편안한 투자를 위한 고민
# 조회수 :  3471
# 날짜 :  2023-05-10 20:18:02
# -----------------------------------------------
# 제목 :  골드만삭스 예상 2030년 대미 수출1위 한국
# 조회수 :  3340
# 날짜 :  2023-05-10 20:09:17
# -----------------------------------------------
# 제목 :  골프존 새로운 테마
# 조회수 :  3103
# 날짜 :  2023-05-10 19:58:18
# -----------------------------------------------
# 제목 :  TrendForce 2Q23에 DRAM 및 NAND 플래시 가격 추가 하락 예상
# 조회수 :  1205
# 날짜 :  2023-05-10 18:27:25
# -----------------------------------------------
# 제목 :  버핏의 버크셔 해서웨이는 1030억 달러의 단기 국채를 보유하고 있는 중
# 조회수 :  3295
# 날짜 :  2023-05-10 17:49:02
# -----------------------------------------------
# 제목 :  오늘의 그림JPG
# 조회수 :  2552
# 날짜 :  2023-05-10 17:02:19
# -----------------------------------------------
# 제목 :  소수점 매수시 외화로 바로 구입가능 할까요미니스탁
# 조회수 :  1342
# 날짜 :  2023-05-10 15:36:26
# -----------------------------------------------
# 제목 :  테슬라 기가텍사스 주당 5천대 생산 달성
# 조회수 :  3037
# 날짜 :  2023-05-10 14:28:23
# -----------------------------------------------
# 제목 :  주식 10년차 주린이가 느낀 것들
# 조회수 :  9500
# 날짜 :  2023-05-10 13:42:40
# -----------------------------------------------
# 제목 :  무조건 숏 포지션입니다
# 조회수 :  8091
# 날짜 :  2023-05-10 12:47:39
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 59 화 영문
# 조회수 :  1253
# 날짜 :  2023-05-10 01:38:53
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 59 화 영문
# 조회수 :  1209
# 날짜 :  2023-05-10 01:37:26
# -----------------------------------------------
# 제목 :  경기침체 단상
# 조회수 :  10.1 k
# 날짜 :  2023-05-10 00:13:17
# -----------------------------------------------
# 제목 :  금리와 주가
# 조회수 :  3946
# 날짜 :  2023-05-09 21:59:36
# -----------------------------------------------
# 제목 :  블룸버그 옥시덴탈 워렌 버핏의 우선주 10억 달러 환매 시작
# 조회수 :  3865
# 날짜 :  2023-05-09 17:56:59
# -----------------------------------------------
# 제목 :  반짝 반등인지 추세적 반등인지 저도 고민입니다
# 조회수 :  3653
# 날짜 :  2023-05-09 11:54:51
# -----------------------------------------------
#
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  5
# 제목 :  채권금리 역전 영어로 Yield curve inversion이 미국은 줄어든건가요
# 조회수 :  1590
# 날짜 :  2023-05-09 10:40:41
# -----------------------------------------------
# 제목 :  워렌 버핏은 왜 은행 파산을 경영자의 책임이라고 주장하는가
# 조회수 :  3470
# 날짜 :  2023-05-09 10:00:58
# -----------------------------------------------
# 제목 :  옛날처럼 일방적으로 당하기만 하는 주주들은 아닙니다
# 조회수 :  2230
# 날짜 :  2023-05-09 09:30:13
# -----------------------------------------------
# 제목 :  루시드 Q123 어닝미스 장 마감 후 869
# 조회수 :  2603
# 날짜 :  2023-05-09 09:27:57
# -----------------------------------------------
# 제목 :  칠레 제헌의회 선거 최종결과feat 좌파의 역사적 참패jpg
# 조회수 :  1259
# 날짜 :  2023-05-09 08:00:33
# -----------------------------------------------
# 제목 :  AMD와 AI
# 조회수 :  3146
# 날짜 :  2023-05-09 05:44:10
# -----------------------------------------------
# 제목 :  지금 미장이 폭락전 반등일까요 진짜 반등일까요
# 조회수 :  6040
# 날짜 :  2023-05-09 05:33:49
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 58 월 영문
# 조회수 :  1018
# 날짜 :  2023-05-09 03:31:57
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 58 월 영문
# 조회수 :  1045
# 날짜 :  2023-05-09 03:29:58
# -----------------------------------------------
# 제목 :  주린이 버핏 옹이 OXY 인수하실 의사 없다고 하셨네요
# 조회수 :  3046
# 날짜 :  2023-05-09 02:02:51
# -----------------------------------------------
# 제목 :  하이닉스 배당이 들어왔네요
# 조회수 :  3476
# 날짜 :  2023-05-08 21:53:13
# -----------------------------------------------
# 제목 :  테슬라의 가격 인상 VS 버핏의 미국 경기에 대한 경고
# 조회수 :  3929
# 날짜 :  2023-05-08 19:49:50
# -----------------------------------------------
# 제목 :  오늘의 그림JPG
# 조회수 :  3157
# 날짜 :  2023-05-08 18:57:56
# -----------------------------------------------
# 제목 :  흔들리는 2차전지
# 조회수 :  3972
# 날짜 :  2023-05-08 18:24:51
# -----------------------------------------------
# 제목 :  5월엔 주식 팔고 떠나라증시 격언 올해도 맞을까
# 조회수 :  4586
# 날짜 :  2023-05-08 16:03:47
# -----------------------------------------------
# 제목 :  미국 노동 시장 공급과 수요에 대한 주 정부 차원의 시각
# 조회수 :  1632
# 날짜 :  2023-05-08 14:13:15
# -----------------------------------------------
# 제목 :  NO 슈가 외치는데설탕값은 왜 오를까
# 조회수 :  2859
# 날짜 :  2023-05-08 13:06:20
# -----------------------------------------------
# 제목 :  애플 4년 수익률 VS 변액보험 19년 수익률
# 조회수 :  4135
# 날짜 :  2023-05-08 12:27:59
# -----------------------------------------------
# 제목 :  삼성전자 뭔 일 있나요
# 조회수 :  7155
# 날짜 :  2023-05-08 08:57:54
# -----------------------------------------------
# 제목 :  긴시간 특정 종목을 이렇게 매집한적은 처음이네요
# 조회수 :  3256
# 날짜 :  2023-05-08 08:09:59
# -----------------------------------------------
# 제목 :  영국 지방선거 최종결과feat 보수당 멸망의 날jpg
# 조회수 :  1529
# 날짜 :  2023-05-08 07:00:35
# -----------------------------------------------
# 제목 :  채권 거래시 궁금함
# 조회수 :  1847
# 날짜 :  2023-05-08 05:26:30
# -----------------------------------------------
# 제목 :  토스증권 랜덤 주식 지급 이벤트 기존 회원 포함 1회
# 조회수 :  3121
# 날짜 :  2023-05-08 02:33:58
# -----------------------------------------------
# 제목 :  INDEXERGO코스닥 빚투인듯
# 조회수 :  3648
# 날짜 :  2023-05-07 23:50:04
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 57 일 영문
# 조회수 :  976
# 날짜 :  2023-05-07 23:33:03
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 57 일 영문
# 조회수 :  904
# 날짜 :  2023-05-07 23:32:14
# -----------------------------------------------
# 제목 :  로이터 미국 은행가는 SEC에 공매도를 조사하고 남용 거래를 줄일 것을 촉구
# 조회수 :  1570
# 날짜 :  2023-05-07 19:57:31
# -----------------------------------------------
# 제목 :  주린이 국내 소부장 업체 관짝에 넣고 못질까지 하려는 모양입니다
# 조회수 :  3653
# 날짜 :  2023-05-07 18:12:40
# -----------------------------------------------
# 제목 :  YNDX 는 어떻게 되는 걸까요
# 조회수 :  1447
# 날짜 :  2023-05-07 18:09:04
# -----------------------------------------------
# 제목 :  우즈베키스탄 개헌 국민투표 최종결과jpg
# 조회수 :  1856
# 날짜 :  2023-05-07 07:00:35
# -----------------------------------------------
#
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  6
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 56 토 영문
# 조회수 :  1258
# 날짜 :  2023-05-07 00:44:57
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 56 토 영문
# 조회수 :  1192
# 날짜 :  2023-05-07 00:43:32
# -----------------------------------------------
# 제목 :  그냥 그어본 차트 선
# 조회수 :  4118
# 날짜 :  2023-05-06 23:48:30
# -----------------------------------------------
# 제목 :  반도체 주가 지극히 개인적 전망
# 조회수 :  5688
# 날짜 :  2023-05-06 18:05:09
# -----------------------------------------------
# 제목 :  주린이 금요일 장 종료 기준으로 거래금액 크신 분들은 숏 상품을 꽤 사셨네요
# 조회수 :  2937
# 날짜 :  2023-05-06 15:55:32
# -----------------------------------------------
# 제목 :  키움증권 오너가 주가조작 연루 의혹에 연락도 없는 사이
# 조회수 :  3440
# 날짜 :  2023-05-06 13:58:49
# -----------------------------------------------
# 제목 :  뉴욕증시애플 실적에 상승나스닥 225 애플 47
# 조회수 :  3398
# 날짜 :  2023-05-06 11:30:44
# -----------------------------------------------
# 제목 :  주식 유튜버 털자 돈다발 우수수250억 어디서 났나 봤더니
# 조회수 :  4639
# 날짜 :  2023-05-06 10:14:37
# -----------------------------------------------
# 제목 :  이탈리아 정치 현황jpg
# 조회수 :  2407
# 날짜 :  2023-05-06 07:00:27
# -----------------------------------------------
# 제목 :  오늘밤 미장 오르는 이유가
# 조회수 :  7323
# 날짜 :  2023-05-06 01:26:43
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 55 금 영문
# 조회수 :  1203
# 날짜 :  2023-05-06 00:10:31
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 55 금 영문
# 조회수 :  1117
# 날짜 :  2023-05-06 00:09:29
# -----------------------------------------------
# 제목 :  라덕연 이 친구 인터뷰 계속 듣고 있자니 말이죠
# 조회수 :  3891
# 날짜 :  2023-05-05 23:00:02
# -----------------------------------------------
# 제목 :  절대 손실을 볼 수 없는 투자
# 조회수 :  6454
# 날짜 :  2023-05-05 21:58:39
# -----------------------------------------------
# 제목 :  지표 미국 평균 시간당 임금 비농업고용지수 실업률 캐나다 고용변동 예측 상회
# 조회수 :  1834
# 날짜 :  2023-05-05 21:34:52
# -----------------------------------------------
# 제목 :  워렌 버핏 CNBC 인터뷰 요약
# 조회수 :  8023
# 날짜 :  2023-05-05 19:34:04
# -----------------------------------------------
# 제목 :  주린이 채권 ETF에도 QYLD처럼 커버드콜 전략으로 월배당 지급하는 종목이 있네요
# 조회수 :  2411
# 날짜 :  2023-05-05 13:21:27
# -----------------------------------------------
# 제목 :  IR iPhone 매출 3월 분기 사상 최고치 경신  서비스 매출 사상 최고치 경신
# 조회수 :  2951
# 날짜 :  2023-05-05 10:15:48
# -----------------------------------------------
# 제목 :  2011년 미국 디폴트 위기 당시 지표
# 조회수 :  4230
# 날짜 :  2023-05-05 08:19:36
# -----------------------------------------------
# 제목 :  애플 실적 생각보다 잘나왔네요
# 조회수 :  4361
# 날짜 :  2023-05-05 07:44:11
# -----------------------------------------------
# 제목 :  캐나다 정치 현황jpg
# 조회수 :  1762
# 날짜 :  2023-05-05 07:30:43
# -----------------------------------------------
# 제목 :  입당 신고합니다
# 조회수 :  1534
# 날짜 :  2023-05-05 03:45:14
# -----------------------------------------------
# 제목 :  5월 2주차 이벤트라고 합니다
# 조회수 :  2352
# 날짜 :  2023-05-05 02:34:15
# -----------------------------------------------
# 제목 :  쿠팡이 잘가네요
# 조회수 :  4736
# 날짜 :  2023-05-05 00:50:45
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 54 목 영문
# 조회수 :  1127
# 날짜 :  2023-05-05 00:50:03
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 54 목 영문
# 조회수 :  1042
# 날짜 :  2023-05-05 00:49:14
# -----------------------------------------------
# 제목 :  그럼에도 연준은 피벗하지 않을겁니다
# 조회수 :  8472
# 날짜 :  2023-05-04 22:35:05
# -----------------------------------------------
# 제목 :  오늘의 증시만평매운맛 버전JPG
# 조회수 :  3668
# 날짜 :  2023-05-04 22:09:22
# -----------------------------------------------
# 제목 :  베이비스텝 밟은 유럽중앙은행 기준금리 연 375로
# 조회수 :  2682
# 날짜 :  2023-05-04 21:48:02
# -----------------------------------------------
# 제목 :  기회는 항상 있습니다
# 조회수 :  3164
# 날짜 :  2023-05-04 20:22:43
# -----------------------------------------------
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  7
# 제목 :  주린이 에너지 종목 며칠 많이 내려왔네요
# 조회수 :  2480
# 날짜 :  2023-05-04 18:55:52
# -----------------------------------------------
# 제목 :  4번째 미 은행 파산 가능성 PacWest은행
# 조회수 :  3299
# 날짜 :  2023-05-04 18:44:19
# -----------------------------------------------
# 제목 :  하반기 마소  메타 서버 주문 축소
# 조회수 :  2847
# 날짜 :  2023-05-04 17:17:18
# -----------------------------------------------
# 제목 :  미국의 상황과 시황관
# 조회수 :  2017
# 날짜 :  2023-05-04 16:50:49
# -----------------------------------------------
# 제목 :  오늘의 증시만평JPG
# 조회수 :  4485
# 날짜 :  2023-05-04 15:58:15
# -----------------------------------------------
# 제목 :  코스피 낙폭 축소하며 2500선 마감코스닥 022 상승 전환
# 조회수 :  1580
# 날짜 :  2023-05-04 15:57:37
# -----------------------------------------------
# 제목 :  부채한도 이슈는 이번엔 크게 터질 가능성이 높습니다
# 조회수 :  3742
# 날짜 :  2023-05-04 14:50:55
# -----------------------------------------------
# 제목 :  주린이 조만간 외화 RP 수시물 46로 오르겠네요
# 조회수 :  1651
# 날짜 :  2023-05-04 14:44:10
# -----------------------------------------------
# 제목 :  22년 양도소득세 신고하라고 왔는데요 수익 40만원입니다
# 조회수 :  4099
# 날짜 :  2023-05-04 10:25:20
# -----------------------------------------------
# 제목 :  찰리 빌렐로가 말하는 진짜 연준의 실책
# 조회수 :  2668
# 날짜 :  2023-05-04 10:21:38
# -----------------------------------------------
# 제목 :  IR QCOM  특히 핸드셋의 수요가 이전에 예측했던 것보다 더 큰 폭으로 악화되고
# 조회수 :  1353
# 날짜 :  2023-05-04 10:16:44
# -----------------------------------------------
# 제목 :  한미 기준금리 추이JPG
# 조회수 :  4232
# 날짜 :  2023-05-04 08:41:56
# -----------------------------------------------
# 제목 :  연방준비제도이사회 FOMC 성명 발표 53
# 조회수 :  2672
# 날짜 :  2023-05-04 08:24:18
# -----------------------------------------------
# 제목 :  프랑스령 폴리네시아 총선하원 재보선 최종결과jpg
# 조회수 :  895
# 날짜 :  2023-05-04 08:00:26
# -----------------------------------------------
# 제목 :  제일 겁나는 시나리오
# 조회수 :  5646
# 날짜 :  2023-05-04 06:23:56
# -----------------------------------------------
# 제목 :  주식한지 딱 4년이네요 올해 장이 좋아서 보유한 전 종목 빨갛네요
# 조회수 :  11.4 k
# 날짜 :  2023-05-04 02:24:57
# -----------------------------------------------
# 제목 :  필립 피셔의 성장 투자 철학 성공적인 기업 선별의 비결을 알아보다
# 조회수 :  1984
# 날짜 :  2023-05-04 02:02:03
# -----------------------------------------------
# 제목 :  거래소 코스피 USD 지수 8일부터 발표 환율 실시간 반영
# 조회수 :  3166
# 날짜 :  2023-05-03 23:26:32
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 53 수 영문
# 조회수 :  1080
# 날짜 :  2023-05-03 23:24:03
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 53 수 영문
# 조회수 :  1019
# 날짜 :  2023-05-03 23:23:09
# -----------------------------------------------
# 제목 :  위기 감지했나글로벌 연기금 中 주식 빠르게 처분
# 조회수 :  4584
# 날짜 :  2023-05-03 22:18:03
# -----------------------------------------------
# 제목 :  지표 미국 ADP 비농업부문 고용 변화  예측보다 상회 예측의 2배
# 조회수 :  2008
# 날짜 :  2023-05-03 21:41:04
# -----------------------------------------------
# 제목 :  주식고수들이 단톡 텔레그램 초대하는 이유가 무엇인가요
# 조회수 :  3282
# 날짜 :  2023-05-03 21:23:33
# -----------------------------------------------
# 제목 :  마지막 금리 인상이라면FOMC 성명서 이 문장이 바뀐다
# 조회수 :  3714
# 날짜 :  2023-05-03 20:28:58
# -----------------------------------------------
# 제목 :  이번이 마지막 금리 인상인가파월의 대답은
# 조회수 :  4418
# 날짜 :  2023-05-03 20:22:29
# -----------------------------------------------
# 제목 :  빌 게이츠 예언이 현실로순식간에 1조원 넘게 증발한 기업은
# 조회수 :  4509
# 날짜 :  2023-05-03 19:55:19
# -----------------------------------------------
# 제목 :  혼돈의 APS 주가
# 조회수 :  1613
# 날짜 :  2023-05-03 19:44:51
# -----------------------------------------------
# 제목 :  선물 장기투자가 tqqq보다 좋다는 말 어떻게보세요
# 조회수 :  2459
# 날짜 :  2023-05-03 18:58:50
# -----------------------------------------------
# 제목 :  조정장에도 외국인 큰손들이 싹쓸이한 종목은
# 조회수 :  3220
# 날짜 :  2023-05-03 18:41:57
# -----------------------------------------------
# 제목 :  비싸다 팔아라SELL고평가 논쟁 불붙는 에코프로비엠
# 조회수 :  2638
# 날짜 :  2023-05-03 18:39:01
# -----------------------------------------------
#
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  8
# 제목 :  코스피 美 은행 위험성 재부각에 하락2500선 후퇴
# 조회수 :  1715
# 날짜 :  2023-05-03 17:42:39
# -----------------------------------------------
# 제목 :  연합 WSJ 티미라오스 딜레마 빠진 연준2006년 참고해야
# 조회수 :  1677
# 날짜 :  2023-05-03 16:45:26
# -----------------------------------------------
# 제목 :  신나는 종가배팅
# 조회수 :  2453
# 날짜 :  2023-05-03 16:09:59
# -----------------------------------------------
# 제목 :  K배터리 3사 1분기 세계 시장점유율 247LG엔솔 2위3위
# 조회수 :  3087
# 날짜 :  2023-05-03 15:29:53
# -----------------------------------------------
# 제목 :  아이칸 힌덴버그에 저격 당해공매도로 주가 폭락
# 조회수 :  2744
# 날짜 :  2023-05-03 13:38:20
# -----------------------------------------------
# 제목 :  여보세력 나야 패러디에임창정 측 형사 고소할 것 분노gisa
# 조회수 :  4497
# 날짜 :  2023-05-03 11:39:45
# -----------------------------------------------
# 제목 :  실적발표 AMD GAAP 기준 009달러 NonGAAP 기준 060달러
# 조회수 :  1549
# 날짜 :  2023-05-03 10:44:58
# -----------------------------------------------
# 제목 :  이번 주가조작은 조작단이 당한건가요
# 조회수 :  3991
# 날짜 :  2023-05-03 09:19:47
# -----------------------------------------------
# 제목 :  파라과이 대선 최종결과jpg
# 조회수 :  1342
# 날짜 :  2023-05-03 07:30:29
# -----------------------------------------------
# 제목 :  희토류 대신테슬라 꺼내든 페라이트 전기차 모터 판도 바꿀까
# 조회수 :  5510
# 날짜 :  2023-05-03 01:46:15
# -----------------------------------------------
# 제목 :  주린이 미국장 소액 익절했습니다 치킨 35마리
# 조회수 :  5396
# 날짜 :  2023-05-03 01:10:24
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 52 화 영문
# 조회수 :  1552
# 날짜 :  2023-05-03 00:49:50
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 52 화 영문
# 조회수 :  2279
# 날짜 :  2023-05-03 00:48:29
# -----------------------------------------------
# 제목 :  오늘 미 증시는 하락세군요 ㅠㅠ
# 조회수 :  4895
# 날짜 :  2023-05-03 00:19:45
# -----------------------------------------------
# 제목 :  주가조작 종목들이 왜 금감원에 안걸렸을까요
# 조회수 :  3214
# 날짜 :  2023-05-02 23:49:20
# -----------------------------------------------
# 제목 :  라덕연쪽 쩐주들 계속 나오네요
# 조회수 :  4134
# 날짜 :  2023-05-02 22:26:09
# -----------------------------------------------
# 제목 :  이번 주가조작 사건에 대한 개인적인 생각
# 조회수 :  2764
# 날짜 :  2023-05-02 20:14:05
# -----------------------------------------------
# 제목 :  모공펌 SG증권 관련 댓글이라네요JPG
# 조회수 :  4284
# 날짜 :  2023-05-02 19:43:04
# -----------------------------------------------
# 제목 :  CFD 무섭네요 8종목 주가조작 방식
# 조회수 :  4140
# 날짜 :  2023-05-02 18:08:15
# -----------------------------------------------
# 제목 :  코스피 외인기관 매수세에 2520대로 상승오름폭 제한
# 조회수 :  1800
# 날짜 :  2023-05-02 16:15:10
# -----------------------------------------------
# 제목 :  안녕하세요 메타트레이더 사기꾼 이야기입니다
# 조회수 :  2755
# 날짜 :  2023-05-02 15:57:42
# -----------------------------------------------
# 제목 :  SOL 미국배당다우존스 배당금
# 조회수 :  2768
# 날짜 :  2023-05-02 15:49:35
# -----------------------------------------------
# 제목 :  찰리 멍거 버핏과 나는 특별한 시대의 산물 투자 황금기 끝났다
# 조회수 :  2917
# 날짜 :  2023-05-02 15:31:25
# -----------------------------------------------
# 제목 :  화제의 8종목에 관심이 많습니다
# 조회수 :  3320
# 날짜 :  2023-05-02 15:16:16
# -----------------------------------------------
# 제목 :  벤자민 그레이엄의 투자 철학 가치 투자의 아버지와 그의 지혜를 탐구하다
# 조회수 :  1108
# 날짜 :  2023-05-02 14:40:02
# -----------------------------------------------
# 제목 :  호주 중앙은행 금리 25bp 인상 385 예측 미스
# 조회수 :  1791
# 날짜 :  2023-05-02 13:36:58
# -----------------------------------------------
# 제목 :  BTFP 관련 안쉬움님의 주장이 맞았습니다
# 조회수 :  2026
# 날짜 :  2023-05-02 12:04:22
# -----------------------------------------------
# 제목 :  T 배당금 들어왔네요 대신증권
# 조회수 :  2269
# 날짜 :  2023-05-02 10:56:04
# -----------------------------------------------
# 제목 :  미국 최대은행 JP모건 퍼스트리퍼블릭 인수다이먼 은행 위기 거의 끝나
# 조회수 :  2432
# 날짜 :  2023-05-02 09:30:17
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 51 월 영문
# 조회수 :  1105
# 날짜 :  2023-05-02 01:35:21
# -----------------------------------------------
#
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  9
