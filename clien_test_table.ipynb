# %%
import requests
from bs4 import BeautifulSoup
import cx_Oracle
import re

def cleansing_sentence(input_string):
    string_pattern = re.compile(r'[^ㄱ-힣 0-9 a-z A-Z]')
    cleansing_string = string_pattern.sub('', input_string)
    return cleansing_string

def url_parsing(response,url_code):
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        div = soup.select_one('div.list_content')

        titles = div.select('div > div > a > span.subject_fixed')
        counts = div.select('div > div > span.hit')
        date = div.select('div > div > span > span.timestamp')
        # link = div.select('div >div > a.list_subject')
        title_list =[]
    
        i=0
        for title in titles:
            title = cleansing_sentence(title.get_text())
            title_list.append(title.strip())
            counts[i] = counts[i].get_text().strip()
            date[i] = date[i].get_text().strip()
            #link[i] = link[i].get('href')
            print("제목 : ",title_list[i])
            print("조회수 : ",counts[i])
            print("날짜 : ",date[i])
            #print("링크 : ",link[i])
            print("-----------------------------------------------")
        
            i = i + 1
        #db_insert(url_code,title_list, counts,date,link)
        db_insert(url_code,title_list, counts,date)

def db_insert(url_code,title_list, counts, date): # DB 저장 함수(크롤링 추출 자료 INSET)
    conn = cx_Oracle.connect(user='admin', password='Tongbrown@23', dsn='tongbrown_high')

    print('')
    print('DB connect 성공!!')
    print('')

    cs = conn.cursor()
    sql = "INSERT INTO clien_test_table (CODE_URL,DATA_TITLE,DATA_COUNT,DATE_WRITE, EXTRACT_DATE,id) VALUES (:1,:2,:3,:4,TO_CHAR(SYSDATE,'YYYYMMDD'),clien_sequence.NEXTVAL)"

    i = 0
    for title in title_list:
        cs.execute(sql, (url_code, title_list[i], counts[i],date[i]))
        i = i + 1
    print("[%d]건 INSERT 완료" % 30)
    cs.close()
    conn.commit()
    conn.close()

def re_url():
    for page in range(5,10):
        url2 = "https://www.clien.net/service/board/cm_stock?&od=T31&category=0&po={}".format(str(page))
        url_code = "03"
        response = requests.get(url2)
        url_parsing(response,url_code)
        print("\n\n\n\n\n\n",page)

if __name__ == '__main__':
    cx_Oracle.init_oracle_client(lib_dir=r"C:\instantclient-basic-windows.x64-21.9.0.0.0dbru\instantclient_21_9")
    re_url()
# Out:
# 제목 :  로이터 버크셔 해서웨이 중국 BYD 주식 5890만 달러어치 매각
# 조회수 :  3249
# 날짜 :  2023-05-11 14:05:19
# -----------------------------------------------
# 제목 :  주식과는 1도 상관없는 주식 관련 징크스
# 조회수 :  2359
# 날짜 :  2023-05-11 12:43:27
# -----------------------------------------------
# 제목 :  中 4월 생산자물가 36 디플레이션 장기국면
# 조회수 :  2200
# 날짜 :  2023-05-11 12:25:48
# -----------------------------------------------
# 제목 :  CFD랑 신용이랑은 다른 거였네요
# 조회수 :  2025
# 날짜 :  2023-05-11 12:04:42
# -----------------------------------------------
# 제목 :  지표 중국 소비자생산자 물가지수 예측 하회jpg
# 조회수 :  1383
# 날짜 :  2023-05-11 10:53:04
# -----------------------------------------------
# 제목 :  5월 미 CPI 발표 일정
# 조회수 :  2137
# 날짜 :  2023-05-11 09:52:35
# -----------------------------------------------
# -----------------------------------------------
# 제목 :  블룸버그 옥시덴탈 워렌 버핏의 우선주 10억 달러 환매 시작
# 조회수 :  3864
# 날짜 :  2023-05-09 17:56:59
# -----------------------------------------------
# 제목 :  반짝 반등인지 추세적 반등인지 저도 고민입니다
# 조회수 :  3653
# 날짜 :  2023-05-09 11:54:51
# -----------------------------------------------
#
# DB connect 성공!!
#
# [30]건 INSERT 완료
#
#
#
#
#
#
#  5
# 제목 :  채권금리 역전 영어로 Yield curve inversion이 미국은 줄어든건가요
# 조회수 :  1590
# 날짜 :  2023-05-09 10:40:41
# -----------------------------------------------
# 제목 :  워렌 버핏은 왜 은행 파산을 경영자의 책임이라고 주장하는가
# 조회수 :  3465
# 날짜 :  2023-05-09 10:00:58
# -----------------------------------------------
# 제목 :  옛날처럼 일방적으로 당하기만 하는 주주들은 아닙니다
# 조회수 :  2230
# 날짜 :  2023-05-09 09:30:13
# -----------------------------------------------
# 제목 :  루시드 Q123 어닝미스 장 마감 후 869
# 조회수 :  2603
# 날짜 :  2023-05-09 09:27:57
# -----------------------------------------------
# 제목 :  칠레 제헌의회 선거 최종결과feat 좌파의 역사적 참패jpg
# 조회수 :  1259
# 날짜 :  2023-05-09 08:00:33
# -----------------------------------------------
# 제목 :  AMD와 AI
# 조회수 :  3146
# 날짜 :  2023-05-09 05:44:10
# -----------------------------------------------
# 제목 :  지금 미장이 폭락전 반등일까요 진짜 반등일까요
# 조회수 :  6040
# 날짜 :  2023-05-09 05:33:49
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 58 월 영문
# 조회수 :  1018
# 날짜 :  2023-05-09 03:31:57
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 58 월 영문
# 조회수 :  1045
# 날짜 :  2023-05-09 03:29:58
# -----------------------------------------------
# 제목 :  주린이 버핏 옹이 OXY 인수하실 의사 없다고 하셨네요
# 조회수 :  3046
# 날짜 :  2023-05-09 02:02:51
# -----------------------------------------------
# 제목 :  하이닉스 배당이 들어왔네요
# 조회수 :  3476
# 날짜 :  2023-05-08 21:53:13
# -----------------------------------------------
# 제목 :  테슬라의 가격 인상 VS 버핏의 미국 경기에 대한 경고
# 조회수 :  3929
# 날짜 :  2023-05-08 19:49:50
# -----------------------------------------------
# 제목 :  오늘의 그림JPG
# 조회수 :  3157
# 날짜 :  2023-05-08 18:57:56
# -----------------------------------------------
# 제목 :  흔들리는 2차전지
# 조회수 :  3972
# 날짜 :  2023-05-08 18:24:51
# -----------------------------------------------
# 제목 :  5월엔 주식 팔고 떠나라증시 격언 올해도 맞을까
# 조회수 :  4579
# 날짜 :  2023-05-08 16:03:47
# -----------------------------------------------
# 제목 :  미국 노동 시장 공급과 수요에 대한 주 정부 차원의 시각
# 조회수 :  1632
# 날짜 :  2023-05-08 14:13:15
# -----------------------------------------------
# 제목 :  NO 슈가 외치는데설탕값은 왜 오를까
# 조회수 :  2854
# 날짜 :  2023-05-08 13:06:20
# -----------------------------------------------
# 제목 :  애플 4년 수익률 VS 변액보험 19년 수익률
# 조회수 :  4135
# 날짜 :  2023-05-08 12:27:59
# -----------------------------------------------
# 제목 :  삼성전자 뭔 일 있나요
# 조회수 :  7153
# 날짜 :  2023-05-08 08:57:54
# -----------------------------------------------
# 제목 :  긴시간 특정 종목을 이렇게 매집한적은 처음이네요
# 조회수 :  3254
# 날짜 :  2023-05-08 08:09:59
# -----------------------------------------------
# 제목 :  영국 지방선거 최종결과feat 보수당 멸망의 날jpg
# 조회수 :  1529
# 날짜 :  2023-05-08 07:00:35
# -----------------------------------------------
# 제목 :  채권 거래시 궁금함
# 조회수 :  1847
# 날짜 :  2023-05-08 05:26:30
# -----------------------------------------------
# 제목 :  토스증권 랜덤 주식 지급 이벤트 기존 회원 포함 1회
# 조회수 :  3121
# 날짜 :  2023-05-08 02:33:58
# -----------------------------------------------
# 제목 :  INDEXERGO코스닥 빚투인듯
# 조회수 :  3647
# 날짜 :  2023-05-07 23:50:04
# -----------------------------------------------
# 제목 :  미국 신문 비지니스 1면 헤드라인 모음 57 일 영문
# 조회수 :  976
# 날짜 :  2023-05-07 23:33:03
# -----------------------------------------------
# 제목 :  미국 신문 1면 헤드라인 모음 57 일 영문
# 조회수 :  904
# 날짜 :  2023-05-07 23:32:14
# -----------------------------------------------
# 제목 :  로이터 미국 은행가는 SEC에 공매도를 조사하고 남용 거래를 줄일 것을 촉구
# 조회수 :  1570
# 날짜 :  2023-05-07 19:57:31
# -----------------------------------------------
# 제목 :  주린이 국내 소부장 업체 관짝에 넣고 못질까지 하려는 모양입니다
# 조회수 :  3653
# 날짜 :  2023-05-07 18:12:40
# -----------------------------------------------
# 제목 :  YNDX 는 어떻게 되는 걸까요
# 조회수 :  1447
# 날짜 :  2023-05-07 18:09:04
# -----------------------------------------------
# 제목 :  우즈베키스탄 개헌 국민투표 최종결과jpg
# 조회수 :  1856
# 날짜 :  2023-05-07 07:00:35
# -----------------------------------------------
#
# DB connect 성공!!
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In [1], line 69
#      67 if __name__ == '__main__':
#      68     cx_Oracle.init_oracle_client(lib_dir=r"C:\instantclient-basic-windows.x64-21.9.0.0.0dbru\instantclient_21_9")
# ---> 69     re_url()
#
# Cell In [1], line 64, in re_url()
#      62 url_code = "03"
#      63 response = requests.get(url2)
# ---> 64 url_parsing(response,url_code)
#      65 print("\n\n\n\n\n\n",page)
#
# Cell In [1], line 38, in url_parsing(response, url_code)
#      36     i = i + 1
#      37 #db_insert(url_code,title_list, counts,date,link)
# ---> 38 db_insert(url_code,title_list, counts,date)
#
# Cell In [1], line 52, in db_insert(url_code, title_list, counts, date)
#      50 i = 0
#      51 for title in title_list:
# ---> 52     cs.execute(sql, (url_code, title_list[i], counts[i],date[i]))
#      53     i = i + 1
#      54 print("[%d]건 INSERT 완료" % 30)
#
# IntegrityError: ORA-00001: unique constraint (ADMIN.SYS_C0036972) violated
