# %%
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup
from urllib.parse import quote
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time
import random
import requests
import cx_Oracle
import re

# 최신 크롬 드라이버 사용하도록 세팅: 현재 OS에 설치된 크롬 브라우저 버전에 맞게 cache에 드라이버 설치
from selenium.webdriver.chrome.service import Service
service = Service(ChromeDriverManager().install())

def cleansing_sentence(input_string):
    string_pattern = re.compile(r'[^ㄱ-힣 0-9 a-z A-Z]')
    cleansing_string = string_pattern.sub('', input_string)
    return cleansing_string

def scroll():
    try:        
        # 페이지 내 스크롤 높이 받아오기
        last_page_height = driver.execute_script("return document.documentElement.scrollHeight")
        while True:
            # 임의의 페이지 로딩 시간 설정
            # PC환경에 따라 로딩시간 최적화를 통해 scraping 시간 단축 가능
            pause_time = random.uniform(1, 2)
            # 페이지 최하단까지 스크롤
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
            # 페이지 로딩 대기
            time.sleep(pause_time)
            # 무한 스크롤 동작을 위해 살짝 위로 스크롤(i.e., 페이지를 위로 올렸다가 내리는 제스쳐)
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight-50)")
            time.sleep(pause_time)
            # 페이지 내 스크롤 높이 새롭게 받아오기
            new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
            # 스크롤을 완료한 경우(더이상 페이지 높이 변화가 없는 경우)
            if new_page_height == last_page_height:
                print("스크롤 완료")
                break
                
            # 스크롤 완료하지 않은 경우, 최하단까지 스크롤
            else:
                last_page_height = new_page_height
            
    except Exception as e:
        print("에러 발생: ", e)

#원하는 검색어 입력받음
query = input()

chrome_options = webdriver.ChromeOptions()

#전체 화면으로 크롬 브라우저 실행
chrome_options.add_argument('--start-maximized')
driver = webdriver.Chrome('C:/Users/effor/바탕 화면/통브라운/chromedriver.exe', chrome_options=chrome_options)

#URL 지정
URL = f"https://www.youtube.com/results?search_query={quote(query)}"

#URL 실행
driver.get(URL)

#필터 버튼 클릭
driver.find_element(By.XPATH, '//*[@id="container"]/ytd-toggle-button-renderer/yt-button-shape/button/yt-touch-feedback-shape/div/div[2]').click()
sleep(1)

#이번 달
upload_date = driver.find_element(By.XPATH,'//*[@id="collapse-content"]/ytd-search-filter-group-renderer[1]')
click_list_1 = upload_date.find_elements(By.ID,"endpoint")
click_list_1[3].click()
sleep(1)

# 무한 스크롤 함수 실행
scroll()

# 페이지 소스 추출
html_source = driver.page_source
soup_source = BeautifulSoup(html_source, 'html.parser')

# 콘텐츠 모든 정보
content_total = soup_source.find_all(class_ = 'yt-simple-endpoint style-scope ytd-video-renderer')
content_record_src = soup_source.select("span.inline-metadata-item")
# 콘텐츠 제목만 추출
content_total_title = list(map(lambda data: data.get_text().replace("\n", ""), content_total))
content_record = list(map(lambda data: data.get_text().replace("\n", ""), content_record_src))
# 콘텐츠 링크만 추출
content_total_link = list(map(lambda data: "https://youtube.com" + data["href"], content_total))

i = 0
for title in content_total_title:
    title = cleansing_sentence(content_total_title[i])
    link = content_total_link[i]
    view = content_record[2*i]
    upload_date = content_record[2*i + 1]


    print("제목 : ",title)
    print("조회수 : ",view)
    print("날짜 : ",upload_date)
    print("링크 : ",link)
    print("-----------------------------------------------")
    i = i + 1
# Out:
# 놈놈놈
# C:\Users\effor\AppData\Local\Temp\ipykernel_20152\4080786218.py:61: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/effor/바탕 화면/통브라운/chromedriver.exe', chrome_options=chrome_options)
# C:\Users\effor\AppData\Local\Temp\ipykernel_20152\4080786218.py:61: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('C:/Users/effor/바탕 화면/통브라운/chromedriver.exe', chrome_options=chrome_options)
# 제목 :  개그콘서트 Gag Concert 놈놈놈 20140216
# 조회수 :  조회수 168만회
# 날짜 :  9년 전
# 링크 :  https://youtube.com/watch?v=5NM-Zu1bud8&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  소미씨 안녕하세요 필근이의 동창 주원입니다  ep723725  KBS방송
# 조회수 :  조회수 9.4만회
# 날짜 :  2년 전
# 링크 :  https://youtube.com/watch?v=uMnNSRFyDSA&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  영화 놈놈놈 명장면 혼자 일본군 초토화시키는 정우성  그의 일당백 활약상
# 조회수 :  조회수 15만회
# 날짜 :  4년 전
# 링크 :  https://youtube.com/watch?v=uG8UXAmoN50&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  고등어의 브금 좋은 놈 나쁜 놈 이상한 놈ost
# 조회수 :  조회수 50만회
# 날짜 :  6년 전
# 링크 :  https://youtube.com/watch?v=4EFDVzrLsts&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  좋은 놈 나쁜 놈 이상한 놈  대평원 추격전 FHD
# 조회수 :  조회수 7.7천회
# 날짜 :  1년 전
# 링크 :  https://youtube.com/watch?v=ZPZSEX11rbU&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  The Good  The Bad  The Weird 2008 Full Movie with English subtitle
# 조회수 :  조회수 16만회
# 날짜 :  2년 전
# 링크 :  https://youtube.com/watch?v=hSC51fApNs4&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  정주행 내부자들에서 손 잘리기 전 손가락 먼저 잘렸던 병헌이 형 feat 손가락 귀신ㅋ 좋은 놈 나쁜 놈 이상한 놈 온갖 TMI 썰 풀어 주는 영상 총정리
# 조회수 :  조회수 8.4만회
# 날짜 :  6개월 전
# 링크 :  https://youtube.com/watch?v=f6nzb9XlM8U&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  마지막회 필근아 우리한테 진자 왜 그러는 거야  ep748749  KBS 방송
# 조회수 :  조회수 5.2만회
# 날짜 :  1년 전
# 링크 :  https://youtube.com/watch?v=WVmaRx-g_Cw&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  필근아 여잔 그렇다  ep741743  KBS 방송
# 조회수 :  조회수 2.2만회
# 날짜 :  1년 전
# 링크 :  https://youtube.com/watch?v=q5k8mSN7XQU&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  청소기를 들고다니는거야  ep714716  KBS방송
# 조회수 :  조회수 7.4만회
# 날짜 :  조회수 115회
# 링크 :  https://youtube.com/watch?v=8JGTUZk0im4&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  내가 신랑이 아니라 네가 신랑이야  ep732734  KBS 방송
# 조회수 :  조회수 215만회
# 날짜 :  조회수 290회
# 링크 :  https://youtube.com/watch?v=Tsi590_ip0A&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 금요스트리밍  10년후 몰아보기zip  KBS 방송
# 조회수 :  조회수 661회
# 날짜 :  조회수 4.4만회
# 링크 :  https://youtube.com/watch?v=OqKR1CvfmpU&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  제사에서 거사까지  모음집
# 조회수 :  2년 전
# 날짜 :  조회수 2.5만회
# 링크 :  https://youtube.com/watch?v=Wzg5SXwQPH8&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  찢어죽일 놈  좌이나믹 듀오
# 조회수 :  2년 전
# 날짜 :  조회수 292만회
# 링크 :  https://youtube.com/watch?v=FkL0ooTFb-8&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  개그콘서트 Gag Concert 놈놈놈 20131215
# 조회수 :  2년 전
# 날짜 :  조회수 7만회
# 링크 :  https://youtube.com/watch?v=y-0tNc0WWQU&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  놈놈놈 명장면
# 조회수 :  4개월 전
# 날짜 :  조회수 53만회
# 링크 :  https://youtube.com/watch?v=s9wiDX9rXx8&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  놈놈놈3 입으로 치는 놈과 가끔 잘 치는 놈 매일 치는 놈과 매일 잘 치는 놈 눈치없이 막 댐비는 놈이 붙었다 과연 누가 승자가 될것인가 40도가 넘는 무더위속 대결
# 조회수 :  5개월 전
# 날짜 :  조회수 73만회
# 링크 :  https://youtube.com/watch?v=orn2WkCyAO4&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  필근이를 위해서라면 어디든 우리가 달려갈게  ep717719  KBS방송
# 조회수 :  9년 전
# 날짜 :  조회수 90만회
# 링크 :  https://youtube.com/watch?v=T6W9rDk__Ak&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  오케이콜 필근아 부담갖지마  ep711713  KBS방송
# 조회수 :  6년 전
# 날짜 :  조회수 4.2천회
# 링크 :  https://youtube.com/watch?v=NO9d2jPc9yU&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  MV Sunny Hill써니힐  NomNomNom 놈놈놈
# 조회수 :  2일 전
# 날짜 :  조회수 290회
# 링크 :  https://youtube.com/watch?v=U4DaypnKWDg&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  크큭티비 놈놈놈  필근이의 멋진 친구들  ep735737  KBS 방송
# 조회수 :  조회수 661회
# 날짜 :  조회수 221만회
# 링크 :  https://youtube.com/watch?v=-kV7cHR9P0E&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
# 제목 :  개그콘서트 Gag Concert 놈놈놈 20131124
# 조회수 :  조회수 590회
# 날짜 :  조회수 19만회
# 링크 :  https://youtube.com/watch?v=d2X0F9c0NIs&pp=ygUJ64aI64aI64aI
# -----------------------------------------------
